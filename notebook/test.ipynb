# %%
# import data and cosine similarity matrix
import joblib
import sys
sys.path.append('..')
from src.model import get_recommendations
data=joblib.load('..\\model and data\\data.pkl')
tfidf_matrix = joblib.load('..\\model and data\\tfidf_matrix.pkl')

# %%
# get user input and print recommendations
print(get_recommendations(input("Enter movie name: "),data,tfidf_matrix))
# Out:
# 870                            superman ii
# 10                        superman returns
# 2435      superman iv: the quest for peace
# 1297                          superman iii
# 14                            man of steel
# 1360                                batman
# 9       batman v superman: dawn of justice
# 511                                  x-men
# 1361                                batman
# 119                          batman begins
# Name: title, dtype: object
